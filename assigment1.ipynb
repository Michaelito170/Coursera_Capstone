# %% [markdown]
# Assigment 1

# %%
import requests
from bs4 import BeautifulSoup
import pandas

# %%
website_text = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(website_text,'xml')

table = soup.find('table')
print(table)
# Out:
# <table cellpadding="2" cellspacing="0" rules="all" style="width:100%; border-collapse:collapse; border:1px solid #ccc;">
# <tbody><tr>
# <td style="width:11%; vertical-align:top; color:#ccc;">
# <p><b>M1A</b><br/><span style="font-size:85%;"><i>Not assigned</i></span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top; color:#ccc;">
# <p><b>M2A</b><br/><span style="font-size:85%;"><i>Not assigned</i></span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top;">
# <p><b>M3A</b><br/><span style="font-size:85%;"><a href="/wiki/North_York" title="North York">North York</a><br/>(<a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>)</span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top;">
# <p><b>M4A</b><br/><span style="font-size:85%;"><a href="/wiki/North_York" title="North York">North York</a><br/>(<a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>)</span>
# </p>
# </td>
# <td style="width:11%; vertical-align:top;">
# ...

# %%
table_rows = table.find_all('tr')
data = []
for row in table_rows:
    td=[]
    for t in row.find_all('td'):
        td.append(t.text.strip())
    data.append(td)
    for inp in td:
        dat1 = inp[:3]
        dat2 = inp[3:].split(sep = "(")[0]
        if inp[3:].split(sep = "(")[0] == "Not assigned":
            dat3 = "na"
        else:
            dat3 = inp[3:].split(sep = "(")[1][:-1]
        data.append([dat1, dat2, dat3])
df = pandas.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighborhood'])
df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-78-75e81cd432d5> in <module>
#      14             dat3 = inp[3:].split(sep = "(")[1][:-1]
#      15         data.append([dat1, dat2, dat3])
# ---> 16 df = pandas.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighborhood'])
#      17 df
#
# ~\Miniconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# ~\Miniconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
# ...

# %%
df = df[~df['Borough'].isnull()]  # to filter out bad rows
df.drop(df[df.Borough == 'Not assigned'].index, inplace=True)
df.reset_index(drop=True, inplace=True)
df = df.groupby(['PostalCode','Borough'])['Neighborhood'].apply(lambda x: ','.join(x)).reset_index()
df['Neighborhood'].replace('Not assigned',df['Borough'],inplace=True)
df['Neighborhood'] = df['Neighborhood'].str.replace("/", ",")
df
# Out:
#     PostalCode                                            Borough  \
# 0          M1B                                        Scarborough
# 1          M1C                                        Scarborough
# 2          M1E                                        Scarborough
# 3          M1G                                        Scarborough
# 4          M1H                                        Scarborough
# 5          M1J                                        Scarborough
# 6          M1K                                        Scarborough
# 7          M1L                                        Scarborough
# 8          M1M                                        Scarborough
# 9          M1N                                        Scarborough
# 10         M1P                                        Scarborough
# 11         M1R                                        Scarborough
# 12         M1S                                        Scarborough
# ...

# %% [markdown]
# Part 2

# %%
import pandas as pd
coordinates = pd.read_csv('Geospatial_Coordinates.csv')

# %%
coordinates.loc[df["PostalCode"] == 'M1B']
newDf = []
for row in df.iterrows():
    coor = coordinates.loc[df["PostalCode"] == row[1]['PostalCode']]
    newDf.append([row[1]['PostalCode'], row[1]['Borough'], row[1]['Neighborhood'] ,coor['Latitude'].values[0], coor['Longitude'].values[0]])
newDf = pandas.DataFrame(newDf, columns=['PostalCode', 'Borough', 'Neighborhood', 'lat', 'lng'])
newDf
# Out:
#     PostalCode                                            Borough  \
# 0          M1B                                        Scarborough
# 1          M1C                                        Scarborough
# 2          M1E                                        Scarborough
# 3          M1G                                        Scarborough
# 4          M1H                                        Scarborough
# 5          M1J                                        Scarborough
# 6          M1K                                        Scarborough
# 7          M1L                                        Scarborough
# 8          M1M                                        Scarborough
# 9          M1N                                        Scarborough
# 10         M1P                                        Scarborough
# 11         M1R                                        Scarborough
# 12         M1S                                        Scarborough
# ...
